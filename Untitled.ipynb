# %%
from utils.config import opt
#from utils.vis_tool import vis_bbox
from utils.dataset import Dataset
import cv2
import numpy as np
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
# 原始图片

pth = 'E:/data/voc07/VOCdevkit/VOC2007/JPEGImages/000001.jpg'
img0 = cv2.imread(pth)
print(img0.shape)
bbox0 = [[48,240,195,371],[8,12,352,498]]

for i in range(len(bbox0)):
    x1, y1, x2, y2 = int(bbox0[i][0]), int(bbox0[i][1]), int(bbox0[i][2]), int(bbox0[i][3])
    cv2.rectangle(img0, (x1,y1), (x2,y2), (255,0,0), 2)
plt.imshow(img0)
plt.show()
# Out:
# (500, 353, 3)

# %%
dataset = Dataset(opt, split='one')

# %%
img, im_info, gt_boxes, num_boxes = dataset[0]

# %%
plt.imshow(img.transpose(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
gt_boxes
# Out:
# array([[270.25497 , 406.30002 , 520.11334 , 629.      ,  12.      ],
#        [  3.399414,  18.7     , 588.102   , 844.9     ,  15.      ]],
#       dtype=float32)

# %%
img2 = np.ones([850,600,3]);img2.shape
# Out:
# (850, 600, 3)

# %%
bbox1 = gt_boxes[:,:-1]
for i in range(len(bbox1)):
    x1,y1, x2, y2 = int(bbox1[i][0]), int(bbox1[i][1]), int(bbox1[i][2]), int(bbox1[i][3])
    print(x1, y1, x2, y2)
    cv2.rectangle(img2, (x1,y1), (x2,y2), (0,255,0), 2)
plt.imshow(img2)
plt.show()
# Out:
# 270 406 520 629
# 3 18 588 844
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
